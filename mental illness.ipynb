# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
illness = pd.read_csv('1- mental-illnesses-prevalence.csv')

# %%
illness.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %%
illness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6420 entries, 0 to 6419
# Data columns (total 8 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Entity                                                                             6420 non-null   object
#  1   Code                                                                               6150 non-null   object
#  2   Year                                                                               6420 non-null   int64
#  3   Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  6420 non-null   float64
#  4   Depressive disorders (share of population) - Sex: Both - Age: Age-standardized     6420 non-null   float64
# ...

# %%
illness.describe()
# Out:
#               Year  \
# count  6420.000000
# mean   2004.500000
# std       8.656116
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        6420.000000
# mean                                            0.266604
# std                                             0.039383
# min                                             0.188416
# 25%                                             0.242267
# 50%                                             0.273477
# 75%                                             0.286575
# max                                             0.462045
#
#        Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        6420.000000
# mean                                            3.767036
# ...

# %%
sns.jointplot(x='Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized', y='Eating disorders (share of population) - Sex: Both - Age: Age-standardized', data=illness, alpha=0.5)

# %%
sns.jointplot(x='Depressive disorders (share of population) - Sex: Both - Age: Age-standardized', y='Eating disorders (share of population) - Sex: Both - Age: Age-standardized', data=illness, alpha=0.5)

# %%
sns.pairplot(illness, 
             kind='scatter', 
             plot_kws={'alpha':0.4}, 
             diag_kws={'alpha':0.55, 'bins':40})

# %%
# Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized vs Eating disorders (share of population) - Sex: Both - Age: Age-standardized
sns.lmplot(x='Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized', 
           y='Eating disorders (share of population) - Sex: Both - Age: Age-standardized', 
           data=illness,
           scatter_kws={'alpha':0.3})

# %%
from sklearn.model_selection import train_test_split

# %%
illness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6420 entries, 0 to 6419
# Data columns (total 8 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Entity                                                                             6420 non-null   object
#  1   Code                                                                               6150 non-null   object
#  2   Year                                                                               6420 non-null   int64
#  3   Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  6420 non-null   float64
#  4   Depressive disorders (share of population) - Sex: Both - Age: Age-standardized     6420 non-null   float64
# ...

# %%
X = illness[['Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized', 'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized', 'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized', 'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized']]
y = illness['Eating disorders (share of population) - Sex: Both - Age: Age-standardized']

# %%
X.head()
y.head()
# Out:
# 0    0.127700
# 1    0.123256
# 2    0.118844
# 3    0.115089
# 4    0.111815
# Name: Eating disorders (share of population) - Sex: Both - Age: Age-standardized, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# the coefficients
lm.coef_
# Out:
# array([1.43837159, 0.00574904, 0.02028292, 0.31392182])

# %%
# r squared
lm.score(X, y)
# Out:
# 0.6561340327631484

# %%
# The coefficients in a dataframe
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coef'])
print(cdf)
# Out:
#                                                         Coef
# Schizophrenia disorders (share of population) -...  1.438372
# Depressive disorders (share of population) - Se...  0.005749
# Anxiety disorders (share of population) - Sex: ...  0.020283
# Bipolar disorders (share of population) - Sex: ...  0.313922

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X_train)
model = sm.OLS(y_train, X)
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                                         OLS Regression Results
# ...
# Dep. Variable:     Eating disorders (share of population) - Sex: Both - Age: Age-standardized   R-squared:                       0.648
# Model:                                                                                    OLS   Adj. R-squared:                  0.648
# Method:                                                                         Least Squares   F-statistic:                     2069.
# Date:                                                                        Mon, 21 Jul 2025   Prob (F-statistic):               0.00
# Time:                                                                                10:09:09   Log-Likelihood:                 4820.5
# No. Observations:                                                                        4494   AIC:                            -9631.
# ...

# %%
predictions = lm.predict(X_test)

# %%
# Scatter plot of actual values of y vs predicted values.
sns.scatterplot(x=y_test, y=predictions)
plt.ylabel('Predictions')
plt.title('Eating disorders (share of population) - Sex: Both - Age: Age-standardized vs. Model Predictions')
# Out:
# Text(0.5, 1.0, 'Eating disorders (share of population) - Sex: Both - Age: Age-standardized vs. Model Predictions')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, predictions))
print('Mean Squared Error:',mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 0.05152248711799118
# Mean Squared Error: 0.005957236215792156
# Root Mean Squared Error: 0.07718313427033238

# %%
residuals = y_test-predictions
sns.distplot(residuals, bins=30)
# Out:
# C:\Users\JOANNAH MARIE\AppData\Local\Temp\ipykernel_5768\339810671.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, bins=30)
# <Axes: xlabel='Eating disorders (share of population) - Sex: Both - Age: Age-standardized', ylabel='Density'>

# %%
import pylab 
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=pylab)
pylab.show()
